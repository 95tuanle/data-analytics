# %% [markdown]
# # Lab 5
#
# Please read the following instructions:
# - Lab notebooks will be graded.
# - Remember to Execute and Save each cell.
# - Submit the .pdf format of saved cells (File->Download as) via Blackboard before the deadline of each lab. You can also save the page as a .pdf file by printing the html page as a pdf file (Ctrl+p -> save as a pdf).
# - Submissions other than .pdf will be graded as 0.
# - Name the submission file as: Firstname_Lastname_LX_Y where Firstname is your first name, last name is your last name, X is the lab number, and Y is the initial of lecture day. For example, Lab 4 submission for John Smith who attends the Mondays lectures is: John_Smith_L4_M.pdf
# - Submissions not following the above naming format will be graded as 0.

# %% [markdown]
# ## Import Numpy, Panda and Matplotlib library

# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Import Dataset

# %% [markdown]
# Read the iris.csv file as a dataframe and print the list of its columns.

# %%
iris = pd.read_csv('iris.csv')
iris.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %% [markdown]
# Print the top 5 rows of the dataframe.

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# ## Exercises 1

# %% [markdown]
# Plot the distribution of the 'sepal.width' column.

# %%
sns.distplot(iris['sepal.width'])
# Out:
# /Users/tuanle/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal.width', ylabel='Density'>

# %%
# Write the code to show the graph below.

# %% [markdown]
# ## Exercises 2

# %% [markdown]
# Plot pairwise bivariate distributions of the 'sepal.length', 'sepal.width', 'petal.length' columns.

# %%
sns.pairplot(iris[['sepal.length', 'sepal.width', 'petal.length']])

# %% [markdown]
# ## Exercises 3

# %% [markdown]
# Plot-box the following columns: 'sepal.length', 'sepal.width', 'petal.length', 'petal.width'

# %%
sns.boxplot(data=iris[['sepal.length', 'sepal.width', 'petal.length', 'petal.width']], palette='rainbow', orient='h')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Exercises 4

# %% [markdown]
# Plot pairgrid of the following columns: 'sepal.length', 'sepal.width', 'petal.length', 'petal.width'

# %%
sns.PairGrid(iris[['sepal.length', 'sepal.width', 'petal.length', 'petal.width']]).map(plt.scatter)

# %% [markdown]
# ## Exercises 5

# %% [markdown]
# Write a code to generate the following plot based on hte the following columns: 'sepal.length', 'sepal.width', 'petal.length', 'petal.width'.

# %%
sns.PairGrid(iris[['sepal.length', 'sepal.width', 'petal.length', 'petal.width']]).map_diag(plt.hist).map_upper(plt.scatter).map_lower(sns.kdeplot)
